# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Initialize the Data

# %%
data = {
    'Company_ID': np.arange(1, 13),
    'Company_Name': ['Apple', 'Microsoft', 'Google', 'Amazon', 'Meta', 'IBM', 'Oracle', 'Salesforce', 'Adobe', 'Intel', 'Tesla', 'NVIDIA'],
    'Domain': ['Hardware', 'Software', 'Search Engine', 'E-commerce', 'Social Media', 'AI & Cloud', 'Database', 'CRM', 'Creative Software', 'Semiconductors', 'EV', 'GPUs'],
    'Stock_Price': [244.92, 408.43, 185.29, 228.71, 737.32, 260.64, 173.50, 325.52, 460.16, 23.60, 355.84, 138.92]
}

# %% [markdown]
# # Creating DataFrame

# %%
df = pd.DataFrame(data)
# Display the first few rows of the DataFrame
display(df)
# Out:
#     Company_ID Company_Name             Domain  Stock_Price
# 0            1        Apple           Hardware       244.92
# 1            2    Microsoft           Software       408.43
# 2            3       Google      Search Engine       185.29
# 3            4       Amazon         E-commerce       228.71
# 4            5         Meta       Social Media       737.32
# 5            6          IBM         AI & Cloud       260.64
# 6            7       Oracle           Database       173.50
# 7            8   Salesforce                CRM       325.52
# 8            9        Adobe  Creative Software       460.16
# 9           10        Intel     Semiconductors        23.60
# 10          11        Tesla                 EV       355.84
# 11          12       NVIDIA               GPUs       138.92

# %% [markdown]
# # Scatter plot

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['Company_Name'], df['Stock_Price'], color='blue', alpha=0.6)
plt.xlabel('Company Name')
plt.ylabel('Stock Price')
plt.title('IT Company Stock Prices')
plt.grid(True)
plt.show()

# %% [markdown]
# # Bar chart

# %%
plt.figure(figsize=(10, 5))
plt.bar(df['Company_Name'], df['Stock_Price'], color='green', alpha=0.7)
plt.xlabel('Company Name')
plt.ylabel('Stock Price')
plt.title('Stock Price per IT Company')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(10, 5))
plt.hist(df['Stock_Price'], bins=5, color='purple', alpha=0.7, edgecolor='black')
plt.xlabel('Stock Price')
plt.ylabel('Frequency')
plt.title('Stock Price Distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# # Line plot

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Company_Name'], df['Stock_Price'], marker='o', linestyle='-', color='red')
plt.xlabel('Company Name')
plt.ylabel('Stock Price')
plt.title('Stock Price Trend')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
